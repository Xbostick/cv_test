# %%
import os
import cv2


import glob
import hashlib
import json
import logging
import os
import random
import shutil
import time
from itertools import repeat
from multiprocessing.pool import ThreadPool, Pool
from pathlib import Path
from threading import Thread

import cv2
import numpy as np
import torch
import torch.nn.functional as F
import yaml
from PIL import Image, ExifTags
from torch.utils.data import Dataset
from tqdm import tqdm

IMG_FORMATS = ['bmp', 'jpg', 'jpeg', 'png', 'tif', 'tiff', 'dng', 'webp', 'mpo']  # acceptable image suffixes
VID_FORMATS = ['mov', 'avi', 'mp4', 'mpg', 'mpeg', 'm4v', 'wmv', 'mkv']  # acceptable video suffixes
from ultralytics import YOLO

# %%
def letterbox(im, new_shape=(640, 640), color=(114, 114, 114), auto=True, scaleFill=False, scaleup=True, stride=32):
    # Resize and pad image while meeting stride-multiple constraints
    shape = im.shape[:2]  # current shape [height, width]
    if isinstance(new_shape, int):
        new_shape = (new_shape, new_shape)

    # Scale ratio (new / old)
    r = min(new_shape[0] / shape[0], new_shape[1] / shape[1])
    if not scaleup:  # only scale down, do not scale up (for better val mAP)
        r = min(r, 1.0)

    # Compute padding
    ratio = r, r  # width, height ratios
    new_unpad = int(round(shape[1] * r)), int(round(shape[0] * r))
    dw, dh = new_shape[1] - new_unpad[0], new_shape[0] - new_unpad[1]  # wh padding
    if auto:  # minimum rectangle
        dw, dh = np.mod(dw, stride), np.mod(dh, stride)  # wh padding
    elif scaleFill:  # stretch
        dw, dh = 0.0, 0.0
        new_unpad = (new_shape[1], new_shape[0])
        ratio = new_shape[1] / shape[1], new_shape[0] / shape[0]  # width, height ratios

    dw /= 2  # divide padding into 2 sides
    dh /= 2

    if shape[::-1] != new_unpad:  # resize
        im = cv2.resize(im, new_unpad, interpolation=cv2.INTER_LINEAR)
    top, bottom = int(round(dh - 0.1)), int(round(dh + 0.1))
    left, right = int(round(dw - 0.1)), int(round(dw + 0.1))
    im = cv2.copyMakeBorder(im, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)  # add border
    return im, ratio, (dw, dh)

# %%
class LoadImages:  # for inference
    def __init__(self, path, img_size=640, stride=32, auto=True):
        p = str(Path(path).absolute())  # os-agnostic absolute path
        if '*' in p:
            files = sorted(glob.glob(p, recursive=True))  # glob
        elif os.path.isdir(p):
            files = sorted(glob.glob(os.path.join(p, '*.*')))  # dir
        elif os.path.isfile(p):
            files = [p]  # files
        else:
            raise Exception(f'ERROR: {p} does not exist')

        images = [x for x in files if x.split('.')[-1].lower() in IMG_FORMATS]
        videos = [x for x in files if x.split('.')[-1].lower() in VID_FORMATS]
        ni, nv = len(images), len(videos)

        self.img_size = img_size
        self.stride = stride
        self.files = images + videos
        self.nf = ni + nv  # number of files
        self.video_flag = [False] * ni + [True] * nv
        self.mode = 'image'
        self.auto = auto
        if any(videos):
            self.new_video(videos[0])  # new video
        else:
            self.cap = None
        assert self.nf > 0, f'No images or videos found in {p}. ' \
                            f'Supported formats are:\nimages: {IMG_FORMATS}\nvideos: {VID_FORMATS}'

    def __iter__(self):
        self.count = 0
        return self

    def __next__(self):
        if self.count == self.nf:
            raise StopIteration
        path = self.files[self.count]

        if self.video_flag[self.count]:
            # Read video
            self.mode = 'video'
            ret_val, img0 = self.cap.read()
            if not ret_val:
                self.count += 1
                self.cap.release()
                if self.count == self.nf:  # last video
                    raise StopIteration
                else:
                    path = self.files[self.count]
                    self.new_video(path)
                    ret_val, img0 = self.cap.read()

            self.frame += 1
            print(f'video {self.count + 1}/{self.nf} ({self.frame}/{self.frames}) {path}: ', end='')

        else:
            # Read image
            self.count += 1
            img0 = cv2.imread(path)  # BGR
            assert img0 is not None, 'Image Not Found ' + path
            print(f'image {self.count}/{self.nf} {path}: ', end='')

        # Padded resize
        img = letterbox(img0, self.img_size, stride=self.stride, auto=self.auto)[0]

        # Convert
        img = img.transpose((2, 0, 1))[::-1]  # HWC to CHW, BGR to RGB
        img = np.ascontiguousarray(img)

        return path, img, img0, self.cap

    def new_video(self, path):
        self.frame = 0
        self.cap = cv2.VideoCapture(path)
        self.frames = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT))

    def __len__(self):
        return self.nf  # number of files

# %%
data = LoadImages("./cvtest.avi") # itterable
model = YOLO("yolov5su.pt")

# %%
side_bounds = [
    np.array([[98,716], [924,411], [1130, 467], [403,873]]),
    np.array([[669,981], [1364,426], [1641,451], [1356,1074]]), 
]

passing_bounds = [
     np.array([[0,771], [120,698], [437,838], [0,1115]]),
    np.array([[0,1286], [544,880], [1580,1021], [1520,1508]]),

]

# %%
def ccw(A,B,C):
    return (C.y-A.y) * (B.x-A.x) > (B.y-A.y) * (C.x-A.x)

# Return true if line segments AB and CD intersect
def intersect(A,B,C,D):
    return ccw(A,C,D) != ccw(B,C,D) and ccw(A,B,C) != ccw(A,B,D)

# %%
class Point:
	def __init__(self,x,y):
		self.x = x
		self.y = y

def ccw(A,B,C):
	return (C.y-A.y)*(B.x-A.x) > (B.y-A.y)*(C.x-A.x)

def intersect(A,B,C,D):
# 	print(A.x,B.x,C.x,D.x)
	return ccw(A,C,D) != ccw(B,C,D) and ccw(A,B,C) != ccw(A,B,D)

# %%
def check_cross(img, rect, poly, corner = None, need_points = False):
    rect_t_l = Point(*rect[0:2])
    rect_b_r = Point(*rect[2:4])
    rect_t_r = Point(rect_b_r.x,rect_t_l.y)
    rect_b_l = Point(rect_t_l.x,rect_b_r.y)
    rect_points = [ rect_b_l, rect_t_l, rect_t_r, rect_b_r,]
    poly_points = [Point(x,y) for x,y in poly]
    cross = 0

    if corner == "br":
        if rect_b_r.x > poly_points[2].x and rect_b_r.y > poly_points[2].y:
            cv2.circle(img,(rect_b_r.x,rect_b_r.y), 10, (255,0,255),20)
            cv2.circle(img,(poly_points[2].x,poly_points[2].y),10,(0,0,255),20)
            return 1
        for poly_point_1, poly_point_2, rect_point_1, rect_point_2 in zip(poly_points[2:], [poly_points[3],poly_points[0]], rect_points[2:], [rect_points[3],rect_points[0]]):
                if intersect(poly_point_1, poly_point_2, rect_point_1, rect_point_2):
                    cv2.line(img, (poly_point_1.x, poly_point_1.y),  (poly_point_2.x, poly_point_2.y), (0,0,255),20)
                    cv2.line(img, (rect_point_1.x, rect_point_1.y),  (rect_point_2.x, rect_point_2.y), (0,0,255),20)
                    cross += 1
    elif corner == "tl":
        if rect_b_l.x < poly_points[1].x and rect_b_l.y < poly_points[1].y:
            cv2.circle(img,(rect_b_r.x,rect_b_r.y), 10, (255,0,255),20)
            cv2.circle(img,(poly_points[1].x,poly_points[1].y),10,(0,0,255),20)
            return 1
        for poly_point_1, poly_point_2 in zip(poly_points[:2], poly_points[1:]):
            for rect_point_1, rect_point_2 in zip(rect_points[:2],rect_points[1:]):
                cross += intersect(poly_point_1, poly_point_2, rect_point_1, rect_point_2)
    elif corner == "bl":
        if rect_t_l.x < poly_points[0].x and rect_t_l.y < poly_points[0].y:
            cv2.circle(img,(rect_t_l.x,rect_t_l.y), 10, (255,0,255),20)
            cv2.circle(img,(poly_points[1].x,poly_points[1].y),10,(0,0,255),20)
            return 1
        for poly_point_1, poly_point_2 in zip([poly_points[3], poly_points[0]], poly_points[:2]):
            for rect_point_1, rect_point_2 in zip([rect_points[3], rect_points[0]],rect_points[:2]):
                if intersect(poly_point_1, poly_point_2, rect_point_1, rect_point_2):
                    cv2.line(img, (poly_point_1.x, poly_point_1.y),  (poly_point_2.x, poly_point_2.y), (0,0,255),20)
                    cv2.line(img, (rect_point_1.x, rect_point_1.y),  (rect_point_2.x, rect_point_2.y), (0,0,255),20)
                    cross += 1
    else:
        
        #check bottom_cross(bottom rect side crossing poly):

        for poly_point_1, poly_point_2 in zip(poly_points, poly_points[1:]+ [poly_points[0]]):
            for rect_point_1, rect_point_2 in zip(rect_points, rect_points[1:] + [rect_points[0]]):
                if intersect(poly_point_1, poly_point_2, rect_point_1, rect_point_2):
                    cross += 1
                    # cv2.line(img, (poly_point_1.x, poly_point_1.y),  (poly_point_2.x, poly_point_2.y), (255,0,255),20)
                    # cv2.line(img, (rect_point_1.x, rect_point_1.y),  (rect_point_2.x, rect_point_2.y), (0,0,255),20)
    if need_points:
        return [cross, rect_points, poly_points]
    else:
        return cross

# %%
frame_cars_left = 0
frame_cars_right = 0
frame_passing_cars_left = 0
frame_passing_cars_right = 0
signals_right = 0
signals_left = 0
is_right_car_passed = False
is_left_car_passed = False
is_right_car_passing = False
is_left_car_passing= False
left_timer = 0
right_timer = 0
barrier_delay = 5
is_avalible_to_ride_left = False
is_avalible_to_ride_right = True

# %%
barrier_state = {
    'open' : 1,
    'close' : 0
    }
class barrier():
    def __init__(self, coordinates):
        self.state = barrier_state["close"]
        self.coordinates = coordinates
    def show(self, img):
        if self.state == barrier_state["close"]:
            cv2.line(img, self.coordinates[0], self.coordinates[1],(255, 0, 0), 9)

# %%
left_barier = barrier(((20,677),(411,856)))
right_barier = barrier(((376,967),(1576,1123)))

# %%
import time

# %%
def normalize_box(bound):
    if (bound[2] - bound[0]) * (bound[3] - bound[1]) > 4000:
        norm = 600
        width = (norm - (bound[2] - bound[0]))/2
        heigh = (norm - (bound[3] - bound[1]))/2
        x_l_norm = bound[0] - width
        x_r_norm = bound[2] + width
        y_b_norm = bound[1] - heigh
        y_t_norm = bound[3] + heigh

        return np.array((x_l_norm, y_b_norm, x_r_norm, y_t_norm))
    else:
        return bound

# %%
frame_cars_left = 0
frame_cars_right = 0
frame_passing_cars_left = 0
frame_passing_cars_right = 0
signals_right = 0
signals_left = 0
is_right_car_passed = False
is_left_car_passed = False
is_right_car_passing = False
is_left_car_passing= False
left_timer = 0
right_timer = 0
barrier_delay = 5
is_avalible_to_ride_left = False
is_avalible_to_ride_right = True

data = LoadImages("./cvtest.avi") # itterable
for i,one in enumerate(data):
    name = one[0]
    img = one[2]

    predictions = model.predict(img, classes = [2,7,3], conf = 0.25)
    for pred in predictions:
        is_left_car_passing = False
        is_right_car_passing = False
        if len(pred.boxes.cls):
            for rec in pred.boxes.xyxy:
                rec = rec.cpu().numpy().astype(int)
                left_cross,rect_points,poly_points = check_cross(img,rec, side_bounds[0], need_points=True)
                rect_points = rect_points + [rect_points[0]]      
                poly_points = poly_points + [poly_points[0]]             
                # for p in range(4):
                #     cv2.line(img,(rect_points[p].x,rect_points[p].y), (rect_points[p+1].x, rect_points[p+1].y), (70*p, 0, 255 - 70*p), 20)
                #     cv2.line(img,(poly_points[p].x,poly_points[p].y), (poly_points[p+1].x, poly_points[p+1].y), (70*p,0,255 - 70*p), 20)

                right_cross,rect_points,poly_points = check_cross(img,rec, side_bounds[1], need_points=True)
                rect_points = rect_points + [rect_points[0]]      
                poly_points = poly_points + [poly_points[0]]             
                # for p in range(4):
                #     cv2.line(img,(rect_points[p].x,rect_points[p].y), (rect_points[p+1].x, rect_points[p+1].y), (70*p, 0, 255 - 70*p), 20)
                #     cv2.line(img,(poly_points[p].x,poly_points[p].y), (poly_points[p+1].x, poly_points[p+1].y), (70*p,0,255 - 70*p), 20)

                if ((right_cross >= 3) and (left_cross < right_cross)) or check_cross(img,rec, side_bounds[1], 'br'):
                    frame_cars_right += 1
                    cv2.putText(img, f"Car rightside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    cv2.putText(img, f"Car right cross {right_cross}", (rec[2],rec[1]-20), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    cv2.putText(img, f"Car left cross {left_cross}", (rec[2],rec[1]-40), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    # cv2.putText(img, f"cross {check_cross(img,rec, side_bounds[1], 'br')}", (rec[2],rec[1]-60), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    cv2.rectangle(img,rec[0:2],rec[2:4], (0,255,0),5)
                elif  left_cross >= 3 or check_cross(img,rec, side_bounds[0], 'bl'):
                    frame_cars_left += 1
                    cv2.putText(img, f"Car leftside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    cv2.putText(img, f"Car right cross {right_cross}", (rec[2],rec[1]-20), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    cv2.putText(img, f"Car left cross {left_cross}", (rec[2],rec[1]-40), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                    
                    cv2.rectangle(img,rec[0:2],rec[2:4], (0,255,0),5)
                    
                

                for ind, bound_check in enumerate(passing_bounds):
                    if check_cross(img,rec, bound_check) > 4:
                        if ind == 1:
                                frame_passing_cars_right +=1
                                cv2.putText(img, "Passing car rightside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                        elif ind == 0:
                            frame_passing_cars_left +=1
                            cv2.putText(img, "Passing car leftside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
                                
                        cv2.rectangle(img,rec[0:2],rec[2:4], (0,255,200),5)
        
        for bound in side_bounds:
            cv2.polylines(img,[np.int32(bound)], True,(0,255,0))
        for bound in passing_bounds:
            cv2.polylines(img,[np.int32(bound)], True,(0,255,200))

    # Если машина подьезжает - открываем
    if frame_cars_left > 100:
        signals_left += 1
        cv2.imwrite(f"./photos/signal_left_{signals_left}.jpg", img)
        frame_cars_left = 0
        left_barier.state = barrier_state['open']
        left_timer = time.time()
    if frame_cars_right > 100:
        signals_right += 1
        cv2.imwrite(f"./photos/signal_right_{signals_right}.jpg", img)
        frame_cars_right = 0
        right_barier.state = barrier_state['open']
        right_timer = time.time()

    # Если машина в статусе проезжает(passing), но стоит долго, а шлагбаум закрыт - поднимаем
    if frame_passing_cars_left > 100 and left_barier.state == barrier_state['close']:
        signals_left += 1
        cv2.imwrite(f"./photos/signal_left_{signals_left}.jpg", img)
        frame_passing_cars_left = 0
        left_barier.state = barrier_state['open']
        left_timer = time.time()
    if frame_passing_cars_right > 100 and right_barier.state == barrier_state['close']:
        signals_right += 1
        cv2.imwrite(f"./photos/signal_right_{signals_right}.jpg", img)
        frame_passing_cars_right = 0
        right_barier.state = barrier_state['open']
        right_timer = time.time()
    
    # Если истек таймер и проезжающих машин нет - закрываем шлагбаум

    left_barier.show(img)
    right_barier.show(img)

    if time.time() - left_timer > barrier_delay:
        left_timer = 0
        left_barier.state = barrier_state['close']
    if time.time() - right_timer  > barrier_delay:
        right_timer = 0
        right_barier.state = barrier_state['close']
 
    
    cv2.putText(img, f"Left_signals = {signals_left}, Right_signals = {signals_right}", (1800,50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (36,255,12), 2)
    cv2.imshow(one[0], one[2])
    
    cv2.waitKey(1)  # 1 millisecond
# Out:
# video 1/1 (1/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 52.9ms
# Speed: 3.0ms preprocess, 52.9ms inference, 95.4ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (2/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (3/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (5/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (6/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (7/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (8/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (9/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (10/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (11/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (12/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (13/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (14/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (15/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (16/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (17/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (18/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (19/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (20/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (21/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (22/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (23/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (24/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (25/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (26/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (27/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (28/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (29/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (30/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (31/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (32/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (33/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (34/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (35/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (36/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (37/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (38/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (39/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (40/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (41/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (42/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (43/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (44/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (45/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (46/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (47/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (48/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (49/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (50/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (51/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (52/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (53/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (54/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (55/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (56/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (57/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (58/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (59/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (60/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (61/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (62/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (63/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (64/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (65/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (66/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (67/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (68/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (69/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (70/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (71/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (72/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (73/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (74/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (75/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (76/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (77/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (78/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (79/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (80/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (81/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (82/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (83/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (84/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (85/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (86/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (87/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (88/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (89/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (90/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (91/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (92/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (93/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (94/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (95/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (96/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (97/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (98/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (99/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (100/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (101/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (102/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (103/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (104/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (105/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (106/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (107/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (108/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (109/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (110/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (111/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (112/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (113/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (114/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (115/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (116/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (117/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (118/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (119/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (120/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (121/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (122/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (123/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (124/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (125/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (126/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (127/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (128/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (129/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (130/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (131/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (132/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (133/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (134/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (135/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (136/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (137/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (138/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (139/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (140/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (141/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (142/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (143/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (144/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (145/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (146/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (147/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (148/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 120
#     117 cv2.putText(img, f"Left_signals = {signals_left}, Right_signals = {signals_right}", (1800,50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (36,255,12), 2)
#     118 cv2.imshow(one[0], one[2])
# --> 120 cv2.waitKey(1)  # 1 millisecond
#
# KeyboardInterrupt:
# При выполнении кода в текущей ячейке или предыдущей ячейке ядро аварийно завершило работу.
#
# Проверьте код в ячейках, чтобы определить возможную причину сбоя.
#
# Щелкните <a href='https://aka.ms/vscodeJupyterKernelCrash'>здесь</a>, чтобы получить дополнительные сведения.
#
# Подробнее см. в <a href='command:jupyter.viewOutput'>журнале Jupyter</a>.

# %%
# data = LoadImages("./cvtest.avi") # itterable
# for i,one in enumerate(data):
#     name = one[0]
#     img = one[2]

#     predictions = model.predict(img, classes = [2,7,3], conf = 0.25)
#     for pred in predictions:
#         is_left_car_passing = False
#         is_right_car_passing = False
#         if len(pred.boxes.cls):
#             for rec in pred.boxes.xyxy:
#                 rec = rec.cpu().numpy().astype(int)
#                 for ind, bound_check in enumerate(side_bounds):
#                     if check_cross(rec, bound_check) > 3:
#                         if ind == 0:
#                             if is_left_car_passed:
#                                 frame_cars_left += 1
#                             cv2.putText(img, f"Car leftside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
#                         elif ind == 1:
#                             if is_right_car_passed:
#                                 frame_cars_right += 1
#                             cv2.putText(img, f"Car rightside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
#                         cv2.rectangle(img,rec[0:2],rec[2:4], (0,255,0),5)

#                 for ind, bound_check in enumerate(passing_bounds):
#                     if check_cross(rec, bound_check) > 3:
#                         if ind == 0:
#                                 frame_passing_cars_left +=1
#                                 cv2.putText(img, "Passing car leftside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
#                         elif ind == 1:
#                                 frame_passing_cars_right +=1
#                                 cv2.putText(img, "Passing car rightside", (rec[2],rec[1]-1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
#                         cv2.rectangle(img,rec[0:2],rec[2:4], (0,255,200),5)

#         for bound in side_bounds:
#             cv2.polylines(img,[np.int32(bound)], True,(0,255,0))
#         for bound in passing_bounds:
#             cv2.polylines(img,[np.int32(bound)], True,(0,255,200))

#     cv2.putText(img, f"Left_signals = {signals_left}, Right_signals = {signals_right}", (1800,50), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (36,255,12), 2)
#     cv2.imshow(one[0], one[2])
    
#     cv2.waitKey(1)  # 1 millisecond
#     if is_left_car_passed and frame_cars_left > 100:
#         signals_left += 1
#         cv2.imwrite(f"./photos/signal_left_{signals_left}.jpg", img)
#         frame_cars_left = 0
#         is_left_car_passed = False
#     if is_right_car_passed and frame_cars_right > 100:
#         signals_right += 1
#         cv2.imwrite(f"./photos/signal_right_{signals_right}.jpg", img)
#         frame_cars_right = 0
#         is_right_car_passed = False
    
#     if not is_left_car_passed and frame_passing_cars_left > 10:
#         frame_passing_cars_left = 0
#         is_left_car_passed = True
#     if not is_right_car_passed and frame_passing_cars_right > 10:
#         frame_passing_cars_right = 0
#         is_right_car_passed = True
# Out:
# video 1/1 (1/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 55.8ms
# Speed: 3.0ms preprocess, 55.8ms inference, 90.8ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (2/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (3/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (5/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (6/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (7/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (8/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (9/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (10/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (11/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (12/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (13/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (14/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (15/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (16/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (17/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (18/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (19/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (20/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (21/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (22/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (23/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (24/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (25/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (26/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (27/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (28/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (29/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (30/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (31/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (32/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (33/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (34/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (35/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (36/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (37/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (38/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (39/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (40/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (41/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (42/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (43/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (44/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (45/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (46/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (47/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (48/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (49/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (50/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (51/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (52/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (53/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (54/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (55/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (56/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (57/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (58/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (59/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (60/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (61/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (62/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (63/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (64/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (65/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (66/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (67/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (68/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (69/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (70/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (71/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (72/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (73/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (74/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (75/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (76/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (77/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (78/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (79/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (80/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (81/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (82/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (83/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (84/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (85/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (86/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (87/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (88/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (89/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (90/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (91/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (92/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (93/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (94/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (95/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (96/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (97/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (98/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (99/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (100/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (101/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (102/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (103/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (104/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (105/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (106/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (107/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (108/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (109/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (110/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (111/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (112/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (113/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (114/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (115/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (116/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (117/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (118/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (119/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (120/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (121/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (122/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (123/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (124/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (125/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (126/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (127/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (128/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (129/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (130/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (131/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (132/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (133/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (134/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (135/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (136/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (137/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (138/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 3 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (139/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (140/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (141/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (142/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (143/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (144/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (145/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (146/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (147/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (148/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (149/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (150/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (151/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (152/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (153/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (154/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (155/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (156/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (157/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (158/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (159/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (160/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 4 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (161/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (162/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (163/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (164/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (165/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (166/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (167/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (168/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (169/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (170/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (171/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (172/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (173/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (174/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (175/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (176/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (177/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (178/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (179/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (180/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (181/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (182/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (183/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (184/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (185/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (186/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (187/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (188/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (189/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (190/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (191/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (192/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (193/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (194/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (195/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (196/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (197/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (198/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (199/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (200/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (201/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (202/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (203/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (204/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 0.9ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (205/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (206/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (207/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (208/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (209/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (210/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (211/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (212/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (213/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (214/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (215/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (216/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (217/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (218/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (219/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (220/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (221/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (222/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (223/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (224/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (225/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (226/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (227/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (228/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 3 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (229/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (230/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (231/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (232/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (233/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (234/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (235/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (236/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (237/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (238/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (239/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (240/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (241/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (242/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (243/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (244/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (245/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 2 trucks, 10.0ms
# ...
# video 1/1 (4498/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4499/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4500/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4501/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4502/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4503/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4504/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4505/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4506/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4507/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4508/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4509/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 1 car, 1 truck, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4510/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4511/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 14.0ms
# Speed: 5.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4512/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4513/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4514/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 2 trucks, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4515/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 2 cars, 1 truck, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4516/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# 0: 384x640 3 cars, 1 truck, 28.9ms
# Speed: 1.0ms preprocess, 28.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# video 1/1 (4517/77579) c:\Users\admin\Desktop\test_cv\cvtest.avi:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       3 name = one[0]
#       4 img = one[2]
# ----> 6 predictions = model.predict(img, classes = [2,7,3], conf = 0.25)
#       7 for pred in predictions:
#       8     is_left_car_passing = False
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\engine\model.py:567, in Model.predict(self, source, stream, predictor, **kwargs)
#     565 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     566     self.predictor.set_prompts(prompts)
# --> 567 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\engine\predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\tasks.py:106, in BaseModel.forward(self, x, *args, **kwargs)
#     104 if isinstance(x, dict):  # for cases of training and validating while training.
#     105     return self.loss(x, *args, **kwargs)
# --> 106 return self.predict(x, *args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\tasks.py:124, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     122 if augment:
#     123     return self._predict_augment(x)
# --> 124 return self._predict_once(x, profile, visualize, embed)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\tasks.py:145, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     143 if profile:
#     144     self._profile_one_layer(m, x, dt)
# --> 145 x = m(x)  # run
#     146 y.append(x if m.i in self.save else None)  # save output
#     147 if visualize:
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\modules\block.py:259, in C3.forward(self, x)
#     257 def forward(self, x):
#     258     """Forward pass through the CSP bottleneck with 2 convolutions."""
# --> 259     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\modules\block.py:343, in Bottleneck.forward(self, x)
#     341 def forward(self, x):
#     342     """Applies the YOLO FPN to input data."""
# --> 343     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\ProgramData\miniforge3\envs\cv_test\Lib\site-packages\torch\nn\modules\conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# # https://github.com/Manishankar9977/vehicle-detection-using-YOLOV5/blob/main/vehicle_detection.ipynb

# %%
from ultralytics import YOLO
